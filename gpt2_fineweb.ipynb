# %%
# Use A100 40G GPU

# %%
# %%capture
# !pip install tiktoken datasets

# %%
# !git clone https://github.com/karpathy/build-nanogpt.git
# Out:
# Cloning into 'build-nanogpt'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 132 (delta 69), reused 58 (delta 58), pack-reused 49 (from 1)
# Receiving objects: 100% (132/132), 461.11 KiB | 24.27 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# %cd build-nanogpt
# Out:
# /content/build-nanogpt

# %%
# !python fineweb.py
# Out:
# README.md: 100% 23.2k/23.2k [00:00<00:00, 92.6MB/s]
# Resolving data files: 100% 1630/1630 [00:01<00:00, 1287.77it/s]
# 000_00000.parquet: 100% 2.15G/2.15G [01:41<00:00, 21.3MB/s]
# 001_00000.parquet: 100% 2.15G/2.15G [00:06<00:00, 350MB/s]
# 002_00000.parquet: 100% 2.15G/2.15G [00:06<00:00, 313MB/s]
# 003_00000.parquet: 100% 2.15G/2.15G [00:06<00:00, 340MB/s]
# 004_00000.parquet: 100% 2.15G/2.15G [00:05<00:00, 359MB/s]
# 005_00000.parquet: 100% 2.15G/2.15G [00:06<00:00, 330MB/s]
# 006_00000.parquet: 100% 2.15G/2.15G [00:05<00:00, 374MB/s]
# 007_00000.parquet: 100% 2.15G/2.15G [00:06<00:00, 312MB/s]
# 008_00000.parquet: 100% 2.15G/2.15G [01:34<00:00, 22.9MB/s]
# 009_00000.parquet: 100% 2.15G/2.15G [00:05<00:00, 411MB/s]
# 010_00000.parquet: 100% 2.15G/2.15G [02:10<00:00, 16.5MB/s]
# 011_00000.parquet: 100% 2.15G/2.15G [01:33<00:00, 23.0MB/s]
# 012_00000.parquet: 100% 2.15G/2.15G [00:09<00:00, 221MB/s]
# 013_00000.parquet: 100% 541M/541M [00:01<00:00, 406MB/s]
# ...

# %%
# Remember to open train_gpt2.py and change batch size B from 64 to 32 before running the script.
# This would take 39 out of 40G VRAM, just fit.

# %%
# !python train_gpt2.py
# Out:
# Streaming output truncated to the last 5000 lines.
# step 14223 | loss: 3.073357 | lr 1.4778e-04 | norm: 0.2840 | dt: 3460.59ms | tok/sec: 151502.63
# step 14224 | loss: 3.114320 | lr 1.4774e-04 | norm: 0.2859 | dt: 3461.11ms | tok/sec: 151479.87
# step 14225 | loss: 3.110821 | lr 1.4771e-04 | norm: 0.3182 | dt: 3462.58ms | tok/sec: 151415.40
# step 14226 | loss: 3.116676 | lr 1.4768e-04 | norm: 0.3159 | dt: 3459.62ms | tok/sec: 151544.81
# step 14227 | loss: 3.058642 | lr 1.4764e-04 | norm: 0.3135 | dt: 3460.85ms | tok/sec: 151491.32
# step 14228 | loss: 3.068426 | lr 1.4761e-04 | norm: 0.2845 | dt: 3460.23ms | tok/sec: 151518.23
# step 14229 | loss: 3.125098 | lr 1.4757e-04 | norm: 0.3062 | dt: 3459.46ms | tok/sec: 151551.96
# step 14230 | loss: 3.154744 | lr 1.4754e-04 | norm: 0.3072 | dt: 3461.17ms | tok/sec: 151477.01
# step 14231 | loss: 3.070896 | lr 1.4751e-04 | norm: 0.3335 | dt: 3462.99ms | tok/sec: 151397.45
# ...

# %%
# !ls
# Out:
# edu_fineweb10B	hellaswag     input.txt  play.ipynb   README.md
# fineweb.py	hellaswag.py  log	 __pycache__  train_gpt2.py

# %%
# mount your Google Drive to copy the models and logs

# %%
# %cp -r ./log ../drive/MyDrive/nanogpt
